# %%
import pandas as pd
import numpy as n
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('/Users/lucky/Downloads/fiat500 (1).csv')

# %%
data
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 0        1  lounge            51          882   25000                1
# 1        2     pop            51         1186   32500                1
# 2        3   sport            74         4658  142228                1
# 3        4  lounge            51         2739  160000                1
# 4        5     pop            73         3074  106880                1
# ...    ...     ...           ...          ...     ...              ...
# 1533  1534   sport            51         3712  115280                1
# 1534  1535  lounge            74         3835  112000                1
# 1535  1536     pop            51         2223   60457                1
# 1536  1537  lounge            51         2557   80750                1
# 1537  1538     pop            51         1766   54276                1
#
#             lat        lon  price
# 0     44.907242   8.611560   8900
# 1     45.666359  12.241890   8800
# ...

# %%
data.describe()
# Out:
#                 ID  engine_power  age_in_days             km  previous_owners  \
# count  1538.000000   1538.000000  1538.000000    1538.000000      1538.000000
# mean    769.500000     51.904421  1650.980494   53396.011704         1.123537
# std     444.126671      3.988023  1289.522278   40046.830723         0.416423
# min       1.000000     51.000000   366.000000    1232.000000         1.000000
# 25%     385.250000     51.000000   670.000000   20006.250000         1.000000
# 50%     769.500000     51.000000  1035.000000   39031.000000         1.000000
# 75%    1153.750000     51.000000  2616.000000   79667.750000         1.000000
# max    1538.000000     77.000000  4658.000000  235000.000000         4.000000
#
#                lat          lon         price
# count  1538.000000  1538.000000   1538.000000
# mean     43.541361    11.563428   8576.003901
# std       2.133518     2.328190   1939.958641
# min      36.855839     7.245400   2500.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1538 entries, 0 to 1537
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               1538 non-null   int64
#  1   model            1538 non-null   object
#  2   engine_power     1538 non-null   int64
#  3   age_in_days      1538 non-null   int64
#  4   km               1538 non-null   int64
#  5   previous_owners  1538 non-null   int64
#  6   lat              1538 non-null   float64
#  7   lon              1538 non-null   float64
#  8   price            1538 non-null   int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 108.3+ KB

# %%
data.head(10)
# Out:
#    ID   model  engine_power  age_in_days      km  previous_owners        lat  \
# 0   1  lounge            51          882   25000                1  44.907242
# 1   2     pop            51         1186   32500                1  45.666359
# 2   3   sport            74         4658  142228                1  45.503300
# 3   4  lounge            51         2739  160000                1  40.633171
# 4   5     pop            73         3074  106880                1  41.903221
# 5   6     pop            74         3623   70225                1  45.000702
# 6   7  lounge            51          731   11600                1  44.907242
# 7   8  lounge            51         1521   49076                1  41.903221
# 8   9   sport            73         4049   76000                1  45.548000
# 9  10   sport            51         3653   89000                1  45.438301
#
#          lon  price
# 0   8.611560   8900
# 1  12.241890   8800
# 2  11.417840   4200
# 3  17.634609   6000
# ...

# %%
data.shape
# Out:
# (1538, 9)

# %%
data[('engine_power')].unique()
# Out:
# array([51, 74, 73, 62, 63, 66, 77, 58])

# %%
data.groupby(['engine_power']).count()
# Out:
#                 ID  model  age_in_days    km  previous_owners   lat   lon  \
# engine_power
# 51            1453   1453         1453  1453             1453  1453  1453
# 58               1      1            1     1                1     1     1
# 62              43     43           43    43               43    43    43
# 63               1      1            1     1                1     1     1
# 66               1      1            1     1                1     1     1
# 73              22     22           22    22               22    22    22
# 74              14     14           14    14               14    14    14
# 77               3      3            3     3                3     3     3
#
#               price
# engine_power
# 51             1453
# 58                1
# 62               43
# 63                1
# 66                1
# 73               22
# 74               14
# 77                3

# %%
data2=data.drop(['lat','lon'],axis=1)

# %%
data2
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  price
# 0        1  lounge            51          882   25000                1   8900
# 1        2     pop            51         1186   32500                1   8800
# 2        3   sport            74         4658  142228                1   4200
# 3        4  lounge            51         2739  160000                1   6000
# 4        5     pop            73         3074  106880                1   5700
# ...    ...     ...           ...          ...     ...              ...    ...
# 1533  1534   sport            51         3712  115280                1   5200
# 1534  1535  lounge            74         3835  112000                1   4600
# 1535  1536     pop            51         2223   60457                1   7500
# 1536  1537  lounge            51         2557   80750                1   5990
# 1537  1538     pop            51         1766   54276                1   7900
#
# [1538 rows x 7 columns]

# %%
data3=pd.get_dummies(data2,dtype=int)
data3
# Out:
#         ID  engine_power  age_in_days      km  previous_owners  price  \
# 0        1            51          882   25000                1   8900
# 1        2            51         1186   32500                1   8800
# 2        3            74         4658  142228                1   4200
# 3        4            51         2739  160000                1   6000
# 4        5            73         3074  106880                1   5700
# ...    ...           ...          ...     ...              ...    ...
# 1533  1534            51         3712  115280                1   5200
# 1534  1535            74         3835  112000                1   4600
# 1535  1536            51         2223   60457                1   7500
# 1536  1537            51         2557   80750                1   5990
# 1537  1538            51         1766   54276                1   7900
#
#       model_lounge  model_pop  model_sport
# 0                1          0            0
# ...

# %%
y=data3['price']

# %%
y
# Out:
# 0       8900
# 1       8800
# 2       4200
# 3       6000
# 4       5700
#         ...
# 1533    5200
# 1534    4600
# 1535    7500
# 1536    5990
# 1537    7900
# Name: price, Length: 1538, dtype: int64

# %%
x=data3.drop('price',axis=1)

# %%
x
# Out:
#         ID  engine_power  age_in_days      km  previous_owners  model_lounge  \
# 0        1            51          882   25000                1             1
# 1        2            51         1186   32500                1             0
# 2        3            74         4658  142228                1             0
# 3        4            51         2739  160000                1             1
# 4        5            73         3074  106880                1             0
# ...    ...           ...          ...     ...              ...           ...
# 1533  1534            51         3712  115280                1             0
# 1534  1535            74         3835  112000                1             1
# 1535  1536            51         2223   60457                1             0
# 1536  1537            51         2557   80750                1             1
# 1537  1538            51         1766   54276                1             0
#
#       model_pop  model_sport
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
x_train.shape
# Out:
# (1030, 8)

# %%
y_train.shape
# Out:
# (1030,)

# %%
x_train.head(10)
# Out:
#         ID  engine_power  age_in_days     km  previous_owners  model_lounge  \
# 527    528            51          425  13111                1             1
# 129    130            51         1127  21400                1             1
# 602    603            51         2039  57039                1             0
# 331    332            51         1155  40700                1             1
# 323    324            51          425  16783                1             1
# 1358  1359            51          762  29378                1             1
# 522    523            51          425  18443                1             1
# 584    585            51          397  11997                1             1
# 1236  1237            51         2162  66900                1             1
# 535    536            51          609  35000                1             0
#
#       model_pop  model_sport
# 527           0            0
# 129           0            0
# 602           1            0
# ...

# %%
y_train.head(10)
# Out:
# 527      9990
# 129      9500
# 602      7590
# 331      8750
# 323      9100
# 1358    10900
# 522     10800
# 584      9999
# 1236     8500
# 535     10500
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ypred=reg.predict(x_test)

# %%
ypred
# Out:
# array([ 5899.77964737,  7197.62924574,  9800.37740463,  9731.3210909 ,
#         9979.99951756,  9596.52406572,  9643.73338578, 10050.33073776,
#         9885.56012459,  9311.60470059, 10404.37854317,  7748.77326627,
#         7673.72157177,  6503.76089728,  9604.27208331, 10408.72221178,
#         9599.41735171,  7757.28075206,  4996.66853213, 10502.64231139,
#        10414.2294308 , 10429.36133944,  7596.9398719 ,  9988.21510684,
#         6952.25165624,  9065.16343409,  4772.288312  ,  6940.11525001,
#         7801.10159922,  9604.24792145,  7282.28723062,  5261.84262409,
#         5373.45316982,  5160.91018573,  8909.39762321,  5685.39083778,
#         9831.30377571,  8261.38356615,  6212.08668723,  8480.76861437,
#         9744.32206892,  6748.18993475,  9158.04117106, 10140.92032693,
#         8698.12507001, 10374.43944919,  9131.23457001,  8911.76992913,
#         7039.12870137,  9113.65847445,  9465.38254199, 10336.12580158,
# ...

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,ypred)
# Out:
# 0.8404533110612133

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,ypred)
# Out:
# 585925.1591527027

# %%
result=pd.DataFrame(columns=['price','predicted'])

# %%
result['price']=y_test

# %%
result['predicted']=ypred

# %%
result=result.reset_index()

# %%
result['ID']=result.index

# %%
result
# Out:
#      index  price     predicted   ID
# 0      481   7900   5899.779647    0
# 1       76   7900   7197.629246    1
# 2     1502   9400   9800.377405    2
# 3      669   8500   9731.321091    3
# 4     1409   9700   9979.999518    4
# ..     ...    ...           ...  ...
# 503    291  10900  10075.095125  503
# 504    596   5699   6293.833146  504
# 505   1489   9500   9923.602619  505
# 506   1436   6990   8319.818282  506
# 507    575  10900  10388.994738  507
#
# [508 rows x 4 columns]

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as py

# %%
sns.lineplot(x='ID',y='price',data=result.head(50))
sns.lineplot(x='ID',y='predicted',data=result.head(50))
# Out:
# <Axes: xlabel='ID', ylabel='price'>

# %%
correlation=data3.corr()

# %%
correlation
# Out:
#                        ID  engine_power  age_in_days        km  \
# ID               1.000000     -0.034059    -0.060753 -0.006537
# engine_power    -0.034059      1.000000     0.319190  0.285495
# age_in_days     -0.060753      0.319190     1.000000  0.833890
# km              -0.006537      0.285495     0.833890  1.000000
# previous_owners  0.007803     -0.005030     0.075775  0.097539
# price            0.028516     -0.277235    -0.893328 -0.859373
# model_lounge     0.019193     -0.133321    -0.259863 -0.255746
# model_pop       -0.007142      0.024783     0.108327  0.109024
# model_sport     -0.024718      0.217362     0.313276  0.303874
#
#                  previous_owners     price  model_lounge  model_pop  \
# ID                      0.007803  0.028516      0.019193  -0.007142
# engine_power           -0.005030 -0.277235     -0.133321   0.024783
# age_in_days             0.075775 -0.893328     -0.259863   0.108327
# ...

# %%
import seaborn as sns

# %% [markdown]
# sns.heatmap(correlation,vmax=1,vmin=-1,annot=True,linewidth=-5,cmap='bwr')

# %%
sns.heatmap(correlation,vmax=1,vmin=-1,annot=True,linewidth=-5,cmap='Greens')
# Out:
# <Axes: >

# %%
sns.heatmap(correlation,vmax=1,vmin=-1,annot=True,linewidth=-5,cmap='PiYG')
# Out:
# <Axes: >
